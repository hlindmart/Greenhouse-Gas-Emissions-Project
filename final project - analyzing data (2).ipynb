# %%
# importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # DATA WRANGLNG - FINAL PROJECT

# %%
# import data - GHG emissions data
ghg=pd.read_csv('/Users/hlind/Downloads/GHGemissions.csv')

# %%
ghg.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 0                                            15.2969
# 1                                            15.3514
# 2                                            14.0513
# 3                                            14.0649
# 4                                            14.0222
#
#    Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)  \
# 0                                            15.9612
# 1                                            15.3516
# 2                                            14.0515
# 3                                            14.0650
# 4                                            14.0224
#
#    Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 0                                             2.9907
# ...

# %%
# checking columns w high NA count
pd.isna(ghg).sum()
# Out:
# Country                                                                    0
# Year                                                                       0
# Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)      106
# Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)     106
# Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)                20
# Total CH4 (MtCO2e)                                                       104
# Total N2O (MtCO2e)                                                       103
# Total F-Gas (MtCO2e)                                                       0
# Total CO2 (including Land-Use Change and Forestry) (MtCO2)               103
# Total CH4 (including Land-Use Change and Forestry) (MtCO2e)              241
# Total N2O (including Land-Use Change and Forestry) (MtCO2e)              241
# Energy (MtCO2e)                                                         1173
# ...

# %%
# dropping columns w high NA count
ghg.drop(["Other Fuel Combustion (MtCO2e)", "Transportation (MtCO2)", "Manufacturing/Construction (MtCO2)", "Electricity/Heat (MtCO2)", "Bunker Fuels (MtCO2)", "Energy (MtCO2e)"],axis=1, inplace=True)

# %%
ghg.head()
# Out:
#        Country  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 0                                            15.2969
# 1                                            15.3514
# 2                                            14.0513
# 3                                            14.0649
# 4                                            14.0222
#
#    Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)  \
# 0                                            15.9612
# 1                                            15.3516
# 2                                            14.0515
# 3                                            14.0650
# 4                                            14.0224
#
#    Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 0                                             2.9907
# ...

# %%
# dropping NA values
ghg.dropna(inplace=True)

# %%
# dropping rows based on year
ghg.drop(ghg[ghg['Year'] <2000].index, inplace=True)

# %% [markdown]
# # there's less data than before to work with - but it is much more specific and condensed to work with data from 2000 onward

# %%
ghg.head()
# Out:
#         Country  Year  \
# 10  Afghanistan  2000
# 11  Afghanistan  2001
# 12  Afghanistan  2002
# 13  Afghanistan  2003
# 14  Afghanistan  2004
#
#     Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 10                                            16.6085
# 11                                            15.1394
# 12                                            17.2393
# 13                                            18.0134
# 14                                            17.8962
#
#     Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)  \
# 10                                            16.6092
# 11                                            15.1397
# 12                                            17.2393
# 13                                            18.0134
# 14                                            17.8962
#
#     Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 10                                             0.7584
# ...

# %%
# renaming CH4 column
ghg.rename(columns={"Total CH4 (MtCO2e)":"Total Methane (MtCO2e)"}, inplace=True)

# %%
# renaming N2O column
ghg.rename(columns={"Total N2O (MtCO2e)":"Total Nitrous Oxide (MtCO2e)"}, inplace=True)

# %%
ghg.head()
# Out:
#         Country  Year  \
# 10  Afghanistan  2000
# 11  Afghanistan  2001
# 12  Afghanistan  2002
# 13  Afghanistan  2003
# 14  Afghanistan  2004
#
#     Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 10                                            16.6085
# 11                                            15.1394
# 12                                            17.2393
# 13                                            18.0134
# 14                                            17.8962
#
#     Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)  \
# 10                                            16.6092
# 11                                            15.1397
# 12                                            17.2393
# 13                                            18.0134
# 14                                            17.8962
#
#     Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 10                                             0.7584
# ...

# %% [markdown]
# # second dataset - socio-economic data

# %%
# import data - socio-economic data
ghgEcon=pd.read_csv('/Users/hlind/Downloads/CAIT Country Socio-Economic Data.csv')

# %%
ghgEcon.head()
# Out:
#        Country  Year  Population (People)  GDP-PPP (Million Intl$ (2011))  \
# 0  Afghanistan  1960            8774440.0                             NaN
# 1  Afghanistan  1961            8953544.0                             NaN
# 2  Afghanistan  1962            9141783.0                             NaN
# 3  Afghanistan  1963            9339507.0                             NaN
# 4  Afghanistan  1964            9547131.0                             NaN
#
#    GDP-USD (Million US$ (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 0                           NaN                                        NaN
# 1                           NaN                                        NaN
# 2                           NaN                                        NaN
# 3                           NaN                                        NaN
# 4                           NaN                                        NaN

# %%
# dropping columns based on year
ghgEcon.drop(ghgEcon[ghgEcon['Year'] <2000].index, inplace=True)

# %%
ghgEcon.head()
# Out:
#         Country  Year  Population (People)  GDP-PPP (Million Intl$ (2011))  \
# 40  Afghanistan  2000           20595360.0                             NaN
# 41  Afghanistan  2001           21347782.0                             NaN
# 42  Afghanistan  2002           22202806.0                         23379.0
# 43  Afghanistan  2003           23116142.0                         25353.0
# 44  Afghanistan  2004           24018682.0                         25620.0
#
#     GDP-USD (Million US$ (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 40                           NaN                                        NaN
# 41                           NaN                                        NaN
# 42                        5150.0                                        NaN
# 43                        5585.0                                        NaN
# 44                        5644.0                                        NaN

# %%
# dropping na values
ghgEcon.dropna()
# Out:
#                    Country  Year  Population (People)  \
# 97            Bahamas, The  2004             322400.0
# 98            Bahamas, The  2005             329088.0
# 99            Bahamas, The  2006             335622.0
# 100           Bahamas, The  2007             342049.0
# 146                Belgium  2000           10251250.0
# ...                    ...   ...                  ...
# 9958  Bosnia & Herzegovina  2007            3868665.0
# 9959  Bosnia & Herzegovina  2008            3861201.0
# 9960  Bosnia & Herzegovina  2009            3853446.0
# 9961  Bosnia & Herzegovina  2010            3845929.0
# 9962  Bosnia & Herzegovina  2011            3839322.0
#
#       GDP-PPP (Million Intl$ (2011))  GDP-USD (Million US$ (2005))  \
# 97                            8089.0                        7453.0
# 98                            8364.0                        7706.0
# 99                            8575.0                        7900.0
# ...

# %%
# renaming population column
ghgEcon.rename(columns={"Population (People)":"Population"}, inplace=True)

# %%
# renaming PPP column
ghgEcon.rename(columns={"GDP-PPP (Million Intl$ (2011))":"GDP-PPP (Million Intl (2011))"}, inplace=True)

# %%
# renaming USD column
ghgEcon.rename(columns={"GDP-USD (Million US$ (2005))":"GDP-USD (Million US (2005))"}, inplace=True)

# %%
ghgEcon.head()
# Out:
#         Country  Year  Population  GDP-PPP (Million Intl (2011))  \
# 40  Afghanistan  2000  20595360.0                            NaN
# 41  Afghanistan  2001  21347782.0                            NaN
# 42  Afghanistan  2002  22202806.0                        23379.0
# 43  Afghanistan  2003  23116142.0                        25353.0
# 44  Afghanistan  2004  24018682.0                        25620.0
#
#     GDP-USD (Million US (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 40                          NaN                                        NaN
# 41                          NaN                                        NaN
# 42                       5150.0                                        NaN
# 43                       5585.0                                        NaN
# 44                       5644.0                                        NaN

# %%
# reattempting na drop by subsettng data
ghgEcon.dropna(subset=['GDP-PPP (Million Intl (2011))', 'GDP-USD (Million US (2005))', 'Energy Use (Thous. tonnes oil eq. (ktoe))'])
# Out:
#                    Country  Year  Population  GDP-PPP (Million Intl (2011))  \
# 97            Bahamas, The  2004    322400.0                         8089.0
# 98            Bahamas, The  2005    329088.0                         8364.0
# 99            Bahamas, The  2006    335622.0                         8575.0
# 100           Bahamas, The  2007    342049.0                         8699.0
# 146                Belgium  2000  10251250.0                       383439.0
# ...                    ...   ...         ...                            ...
# 9958  Bosnia & Herzegovina  2007   3868665.0                        34122.0
# 9959  Bosnia & Herzegovina  2008   3861201.0                        35972.0
# 9960  Bosnia & Herzegovina  2009   3853446.0                        34925.0
# 9961  Bosnia & Herzegovina  2010   3845929.0                        35170.0
# 9962  Bosnia & Herzegovina  2011   3839322.0                        35506.0
#
# ...

# %%
ghgEcon.head()
# Out:
#         Country  Year  Population  GDP-PPP (Million Intl (2011))  \
# 40  Afghanistan  2000  20595360.0                            NaN
# 41  Afghanistan  2001  21347782.0                            NaN
# 42  Afghanistan  2002  22202806.0                        23379.0
# 43  Afghanistan  2003  23116142.0                        25353.0
# 44  Afghanistan  2004  24018682.0                        25620.0
#
#     GDP-USD (Million US (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 40                          NaN                                        NaN
# 41                          NaN                                        NaN
# 42                       5150.0                                        NaN
# 43                       5585.0                                        NaN
# 44                       5644.0                                        NaN

# %%
# reattempting na drop (2)
ghgEcon.dropna(inplace=True)

# %%
ghgEcon.head()
# Out:
#           Country  Year  Population  GDP-PPP (Million Intl (2011))  \
# 97   Bahamas, The  2004    322400.0                         8089.0
# 98   Bahamas, The  2005    329088.0                         8364.0
# 99   Bahamas, The  2006    335622.0                         8575.0
# 100  Bahamas, The  2007    342049.0                         8699.0
# 146       Belgium  2000  10251250.0                       383439.0
#
#      GDP-USD (Million US (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 97                        7453.0                                      664.0
# 98                        7706.0                                      696.0
# 99                        7900.0                                      706.0
# 100                       8014.0                                      709.0
# 146                     355035.0                                    58508.0

# %% [markdown]
# # third dataset - ghg inventory

# %%
# importing data - ghg inventory
ghgInv=pd.read_csv('/Users/hlind/Downloads/greenhouse_gas_inventory_data_data.csv')

# %%
ghgInv.head()
# Out:
#   country_or_area  year          value  \
# 0       Australia  2014  393126.946994
# 1       Australia  2013  396913.936530
# 2       Australia  2012  406462.847704
# 3       Australia  2011  403705.528314
# 4       Australia  2010  406200.993184
#
#                                             category
# 0  carbon_dioxide_co2_emissions_without_land_use_...
# 1  carbon_dioxide_co2_emissions_without_land_use_...
# 2  carbon_dioxide_co2_emissions_without_land_use_...
# 3  carbon_dioxide_co2_emissions_without_land_use_...
# 4  carbon_dioxide_co2_emissions_without_land_use_...

# %%
# checking values for year 
ghgInv.year.value_counts()
# Out:
# 2012    345
# 2009    345
# 2008    345
# 2013    345
# 2010    344
# 2006    343
# 2011    343
# 2007    343
# 2003    342
# 2001    342
# 2002    342
# 2004    342
# 2005    342
# 2000    341
# 1999    340
# 1998    339
# 1997    338
# 2014    338
# 1996    336
# 1995    335
# 1994    322
# 1993    317
# 1992    316
# 1991    312
# 1990    309
# Name: year, dtype: int64

# %%
# dropping rows based on year
ghgInv.drop(ghgInv[ghgInv['year'] <2000].index, inplace=True)

# %%
ghgInv.head()
# Out:
#   country_or_area  year          value  \
# 0       Australia  2014  393126.946994
# 1       Australia  2013  396913.936530
# 2       Australia  2012  406462.847704
# 3       Australia  2011  403705.528314
# 4       Australia  2010  406200.993184
#
#                                             category
# 0  carbon_dioxide_co2_emissions_without_land_use_...
# 1  carbon_dioxide_co2_emissions_without_land_use_...
# 2  carbon_dioxide_co2_emissions_without_land_use_...
# 3  carbon_dioxide_co2_emissions_without_land_use_...
# 4  carbon_dioxide_co2_emissions_without_land_use_...

# %%
# renaming country column
ghgInv.rename(columns={"country_or_area":"country"}, inplace=True)

# %%
ghgInv.head()
# Out:
#      country  year          value  \
# 0  Australia  2014  393126.946994
# 1  Australia  2013  396913.936530
# 2  Australia  2012  406462.847704
# 3  Australia  2011  403705.528314
# 4  Australia  2010  406200.993184
#
#                                             category
# 0  carbon_dioxide_co2_emissions_without_land_use_...
# 1  carbon_dioxide_co2_emissions_without_land_use_...
# 2  carbon_dioxide_co2_emissions_without_land_use_...
# 3  carbon_dioxide_co2_emissions_without_land_use_...
# 4  carbon_dioxide_co2_emissions_without_land_use_...

# %%
# the category column has lots of sp. characters - renaming would be beneficial
## recoding category variables
ghgInv.category.value_counts()
# Out:
# carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent     644
# greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent    644
# methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent            644
# nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent      644
# sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent                                                    642
# hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent                                                     629
# greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent                   569
# perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent                                                       516
# ...

# %%
# defining function for rename 
def reName (series):
    if series=="carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent":
        return "CO2 emissions wo LULUCF"
    if series=="greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent":
        return "GHG emissions wo LULUCF"
    if series=="methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent":
        return "Methane emissions wo LULUCF"
    if series=="nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent":
        return "Nitrous oxide emissions wo LULUCF"
    if series=="sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent":
        return "Sulfur emissions"
    if series=="hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent":
        return "HCFS emissions"
    if series=="greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent":
        return "GHG emissions including CO2 wo LULUCF"
    if series=="perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent":
        return "PFCS emissions"
    if series=="nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent":
        return "NF3 emissions"
    if series=="unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent":
        return "Unspecified mix of HCFS and PFCS emissions"

# %%
# defining function for recode
def recode (series):
    if series=="CO2 emissions wo LULUCF":
        return 0
    if series=="GHG emissions wo LULUCF":
        return 1
    if series=="Methane emissions wo LULUCF":
        return 2
    if series=="Nitrous oxide emissions wo LULUCF":
        return 3
    if series=="Sulfur emissions":
        return 4
    if series=="HCFS emissions":
        return 5
    if series=="GHG emissions including CO2 wo LULUCF":
        return 6
    if series=="PFCS emissions":
        return 7
    if series=="NF3 emissions":
        return 8
    if series=="Unspecified mix of HCFS and PFCS emissions":
        return 9

# %%
# attaching reName to data
ghgInv['category']=ghgInv['category'].apply(reName)

# %%
# attaching recode to data
ghgInv['categoryR']=ghgInv['category'].apply(recode)

# %%
ghgInv.head()
# Out:
#      country  year          value                 category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %% [markdown]
# # DATA ANALYSIS - FINAL PROJECT

# %%
# verifying data
ghg.head()
# Out:
#         Country  Year  \
# 10  Afghanistan  2000
# 11  Afghanistan  2001
# 12  Afghanistan  2002
# 13  Afghanistan  2003
# 14  Afghanistan  2004
#
#     Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)  \
# 10                                            16.6085
# 11                                            15.1394
# 12                                            17.2393
# 13                                            18.0134
# 14                                            17.8962
#
#     Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)  \
# 10                                            16.6092
# 11                                            15.1397
# 12                                            17.2393
# 13                                            18.0134
# 14                                            17.8962
#
#     Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)  \
# 10                                             0.7584
# ...

# %%
# renaming columns in 1st dataset to shorten
ghg.rename(columns={"Total GHG Emissions Excluding Land-Use Change and Forestry (MtCO2e)":"Total GHG Emissions wo LULUCF", "Total GHG Emissions Including Land-Use Change and Forestry (MtCO?e?)":"Total GHG Emissions w LULUCF", "Total CO2 (excluding Land-Use Change and Forestry) (MtCO2)":"Total CO2 wo LULUCF", "Total CO2 (including Land-Use Change and Forestry) (MtCO2)":"Total CO2 w LULUCF", "Total CH4 (including Land-Use Change and Forestry) (MtCO2e)":"Total Methane w LULUCF", "Total N2O (including Land-Use Change and Forestry) (MtCO2e)":"Total Nitrous Oxide w LULUCF"}, inplace=True)

# %%
ghg.head()
# Out:
#         Country  Year  Total GHG Emissions wo LULUCF  \
# 10  Afghanistan  2000                        16.6085
# 11  Afghanistan  2001                        15.1394
# 12  Afghanistan  2002                        17.2393
# 13  Afghanistan  2003                        18.0134
# 14  Afghanistan  2004                        17.8962
#
#     Total GHG Emissions w LULUCF  Total CO2 wo LULUCF  Total Methane (MtCO2e)  \
# 10                       16.6092               0.7584                 12.0918
# 11                       15.1397               0.6229                 11.1523
# 12                       17.2393               0.8904                 12.6024
# 13                       18.0134               1.0369                 12.9994
# 14                       17.8962               0.9563                 13.0324
#
#     Total Nitrous Oxide (MtCO2e)  Total F-Gas (MtCO2e)  Total CO2 w LULUCF  \
# 10                        3.7092                0.0491            0.758448
# ...

# %%
ghgEcon.head()
# Out:
#           Country  Year  Population  GDP-PPP (Million Intl (2011))  \
# 97   Bahamas, The  2004    322400.0                         8089.0
# 98   Bahamas, The  2005    329088.0                         8364.0
# 99   Bahamas, The  2006    335622.0                         8575.0
# 100  Bahamas, The  2007    342049.0                         8699.0
# 146       Belgium  2000  10251250.0                       383439.0
#
#      GDP-USD (Million US (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 97                        7453.0                                      664.0
# 98                        7706.0                                      696.0
# 99                        7900.0                                      706.0
# 100                       8014.0                                      709.0
# 146                     355035.0                                    58508.0

# %%
# verifying country value counts
ghgEcon.Country.value_counts()
# Out:
# Sweden                 13
# United States          13
# Hungary                13
# United Kingdom         13
# Korea, Rep. (South)    13
#                        ..
# Gambia, The             4
# Djibouti                4
# Dominica                4
# Fiji                    4
# Bahamas, The            4
# Name: Country, Length: 162, dtype: int64

# %%
ghgInv.head()
# Out:
#      country  year          value                 category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %%
# renaming columns on 3rd data set in order to merge
ghgInv.rename(columns={"country":"Country", "year":"Year", "value":"Value", "category":"Category"}, inplace=True)

# %%
ghgInv.head()
# Out:
#      Country  Year          Value                 Category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %%
# creating new data from existing rows
ghgWorld=ghg[(ghg['Country']=='World')]

# %%
ghgWorld.head()
# Out:
#      Country  Year  Total GHG Emissions wo LULUCF  \
# 4242   World  2000                    33886.61512
# 4243   World  2001                    34257.15087
# 4244   World  2002                    34852.06885
# 4245   World  2003                    36152.10262
# 4246   World  2004                    37607.34796
#
#       Total GHG Emissions w LULUCF  Total CO2 wo LULUCF  \
# 4242                   36679.71736           24758.1186
# 4243                   37366.03728           24999.0583
# 4244                   38123.23356           25439.4626
# 4245                   39449.47109           26612.4680
# 4246                   40841.06103           27879.3783
#
#       Total Methane (MtCO2e)  Total Nitrous Oxide (MtCO2e)  \
# 4242               6142.9188                     2556.7717
# 4243               6212.2279                     2583.1733
# 4244               6290.1929                     2625.8364
# 4245               6366.6770                     2642.4953
# ...

# %%
# dropping rows with WORLD values
ghg.drop(ghg[ghg['Country'] =='World'].index, inplace=True)

# %%
# exporting data 
ghg.to_csv('ghgClean.csv')

# %%
# exporting data
ghgWorld.to_csv('ghgWorld.csv')

# %% [markdown]
# # DATA ANALYSIS 2 - FINAL PROJECT

# %%
ghgInv.head()
# Out:
#      Country  Year          Value                 Category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %%
# checking mean by country
ghgInv.groupby('Country')['Value'].mean()
# Out:
# Country
# Australia                   1.943488e+05
# Austria                     2.835474e+04
# Belarus                     4.332267e+04
# Belgium                     4.808475e+04
# Bulgaria                    1.914426e+04
# Canada                      2.455097e+05
# Croatia                     1.107172e+04
# Cyprus                      3.887221e+03
# Czech Republic              5.193089e+04
# Denmark                     2.447944e+04
# Estonia                     7.894902e+03
# European Union              1.480370e+06
# Finland                     2.714598e+04
# France                      1.760826e+05
# Germany                     2.933741e+05
# Greece                      4.647032e+04
# Hungary                     2.603136e+04
# Iceland                     1.641622e+03
# Ireland                     2.254514e+04
# Italy                       1.760816e+05
# Japan                       4.556798e+05
# Latvia                      4.913580e+03
# Liechtenstein               7.005340e+01
# ...

# %%
## based on data above, Lithuania averaged 9.06 of ghg emissions while the US averaged 2.12
# checking median by country
ghgInv.groupby('Country')['Value'].median()
# Out:
# Country
# Australia                    59240.962604
# Austria                       3571.721463
# Belarus                      36205.608229
# Belgium                       8235.735485
# Bulgaria                      4118.309701
# Canada                       39407.110871
# Croatia                       3029.461752
# Cyprus                         918.036272
# Czech Republic                7568.750825
# Denmark                       7100.226807
# Estonia                       1187.508488
# European Union              174422.087958
# Finland                       5606.722325
# France                       47876.619286
# Germany                      23851.438405
# Greece                        8716.092666
# Hungary                       6917.831888
# Iceland                        516.554895
# Ireland                       7367.668846
# Italy                        23342.093760
# Japan                        24895.576133
# Latvia                        1949.622046
# ...

# %%
## comparing Lithuania to the US, the US has a far higher number than when averaging
# checking year value counts
ghgInv.Year.value_counts()
# Out:
# 2013    345
# 2012    345
# 2009    345
# 2008    345
# 2010    344
# 2011    343
# 2007    343
# 2006    343
# 2005    342
# 2004    342
# 2003    342
# 2002    342
# 2001    342
# 2000    341
# 2014    338
# Name: Year, dtype: int64

# %%
ghgInv.head()
# Out:
#      Country  Year          Value                 Category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %%
# checking value counts for category
ghgInv.Category.value_counts()
# Out:
# CO2 emissions wo LULUCF                       644
# GHG emissions wo LULUCF                       644
# Methane emissions wo LULUCF                   644
# Nitrous oxide emissions wo LULUCF             644
# Sulfur emissions                              642
# HCFS emissions                                629
# GHG emissions including CO2 wo LULUCF         569
# PFCS emissions                                516
# NF3 emissions                                 165
# Unspecified mix of HCFS and PFCS emissions     45
# Name: Category, dtype: int64

# %%
# dropping EU rows 
ghgInv.drop(ghgInv[ghgInv['Country'] =='European Union'].index, inplace=True)

# %%
# verifying
ghgInv.Country.value_counts()
# Out:
# United States of America    150
# Germany                     150
# France                      135
# Japan                       135
# Italy                       135
# Austria                     135
# Canada                      135
# Ireland                     131
# Switzerland                 127
# Belgium                     127
# Czech Republic              123
# Sweden                      120
# Slovenia                    120
# Slovakia                    120
# Russian Federation          120
# Netherlands                 120
# Portugal                    120
# Poland                      120
# Norway                      120
# United Kingdom              120
# New Zealand                 120
# Romania                     120
# Australia                   120
# Iceland                     120
# Hungary                     120
# Greece                      120
# Finland                     120
# Denmark                     120
# Ukraine                     116
# ...

# %%
ghgEcon.head()
# Out:
#           Country  Year  Population  GDP-PPP (Million Intl (2011))  \
# 97   Bahamas, The  2004    322400.0                         8089.0
# 98   Bahamas, The  2005    329088.0                         8364.0
# 99   Bahamas, The  2006    335622.0                         8575.0
# 100  Bahamas, The  2007    342049.0                         8699.0
# 146       Belgium  2000  10251250.0                       383439.0
#
#      GDP-USD (Million US (2005))  Energy Use (Thous. tonnes oil eq. (ktoe))
# 97                        7453.0                                      664.0
# 98                        7706.0                                      696.0
# 99                        7900.0                                      706.0
# 100                       8014.0                                      709.0
# 146                     355035.0                                    58508.0

# %%
ghgInv.head()
# Out:
#      Country  Year          Value                 Category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %%
# creating new data set out of top 3 contributors of ghg emissions
## recoding countries
def countryR (series):
    if series=="United States":
        return 0
    if series=="Russian Federation":
        return 1
    if series=="Japan":
        return 2

# %%
# applying recode
ghg['CountryR']=ghg['Country'].apply(countryR)

# %%
# dropping nas
ghgR=ghg.dropna()

# %%
ghgR.head()
# Out:
#      Country  Year  Total GHG Emissions wo LULUCF  \
# 1965   Japan  2000                      1313.3872
# 1966   Japan  2001                      1294.9110
# 1967   Japan  2002                      1327.8202
# 1968   Japan  2003                      1331.6791
# 1969   Japan  2004                      1330.5514
#
#       Total GHG Emissions w LULUCF  Total CO2 wo LULUCF  \
# 1965                     1239.3223            1211.0103
# 1966                     1195.8475            1194.5759
# 1967                     1228.6576            1228.8536
# 1968                     1232.4578            1234.4257
# 1969                     1231.2040            1234.6532
#
#       Total Methane (MtCO2e)  Total Nitrous Oxide (MtCO2e)  \
# 1965                 27.2842                       25.0611
# 1966                 26.4170                       24.1296
# 1967                 25.8427                       23.5786
# 1968                 25.2151                       22.7362
# ...

# %%
# exporting data
ghgR.to_csv('ghgR.csv')

# %%
# creating data set to export 
ghgInv1=ghgInv.drop(ghgInv[ghgInv['Country']=='European Union'].index)

# %%
ghgInv1.head()
# Out:
#      Country  Year          Value                 Category  categoryR
# 0  Australia  2014  393126.946994  CO2 emissions wo LULUCF          0
# 1  Australia  2013  396913.936530  CO2 emissions wo LULUCF          0
# 2  Australia  2012  406462.847704  CO2 emissions wo LULUCF          0
# 3  Australia  2011  403705.528314  CO2 emissions wo LULUCF          0
# 4  Australia  2010  406200.993184  CO2 emissions wo LULUCF          0

# %%
ghgInv1.Country.value_counts()
# Out:
# United States of America    150
# Germany                     150
# France                      135
# Japan                       135
# Italy                       135
# Austria                     135
# Canada                      135
# Ireland                     131
# Switzerland                 127
# Belgium                     127
# Czech Republic              123
# Sweden                      120
# Slovenia                    120
# Slovakia                    120
# Russian Federation          120
# Netherlands                 120
# Portugal                    120
# Poland                      120
# Norway                      120
# United Kingdom              120
# New Zealand                 120
# Romania                     120
# Australia                   120
# Iceland                     120
# Hungary                     120
# Greece                      120
# Finland                     120
# Denmark                     120
# Ukraine                     116
# ...

# %%
# exporting data
ghgInv1.to_csv('ghgInv1.csv')
